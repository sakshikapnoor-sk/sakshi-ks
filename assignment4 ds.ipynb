# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv('Patient_Data.csv')

# %%
df1.shape
# Out:
# (6, 7)

# %%
df1.head()
# Out:
#    PatientID     Name   Department     Doctor  BillAmount  ReceptionistID  \
# 0        101    Alice   Cardiology  Dr. Smith      5000.0               1
# 1        102      Bob    Neurology   Dr. John         NaN               2
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0               1
# 3        104    David   Cardiology  Dr. Smith      6200.0               3
# 4        105      Eva  Dermatology   Dr. Rose         NaN               2
#
#         CheckInTime
# 0  2023-01-10 09:00
# 1  2023-01-11 10:30
# 2  2023-01-12 11:00
# 3  2023-01-13 12:00
# 4  2023-01-14 08:45

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PatientID       6 non-null      int64
#  1   Name            6 non-null      object
#  2   Department      6 non-null      object
#  3   Doctor          6 non-null      object
#  4   BillAmount      4 non-null      float64
#  5   ReceptionistID  6 non-null      int64
#  6   CheckInTime     6 non-null      object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 468.0+ bytes

# %%
df2=pd.read_csv('Billing_Data.csv')

# %%
df2.shape
# Out:
# (5, 3)

# %%
df2.head()
# Out:
#    PatientID  InsuranceCovered  FinalAmount
# 0        101              2000         3000
# 1        102              1500         3500
# 2        103              2500         5000
# 3        104              3000         3200
# 4        105              1000         4000

# %%
df1.columns
# Out:
# Index(['PatientID', 'Name', 'Department', 'Doctor', 'BillAmount',
#        'ReceptionistID', 'CheckInTime'],
#       dtype='object')

# %%
selected_columns=df1[['PatientID','Department','Doctor','BillAmount']]
selected_columns
# Out:
#    PatientID   Department     Doctor  BillAmount
# 0        101   Cardiology  Dr. Smith      5000.0
# 1        102    Neurology   Dr. John         NaN
# 2        103  Orthopedics    Dr. Lee      7500.0
# 3        104   Cardiology  Dr. Smith      6200.0
# 4        105  Dermatology   Dr. Rose         NaN
# 5        101   Cardiology  Dr. Smith      5000.0

# %%
df1=df1.drop(columns=['ReceptionistID', 'CheckInTime'])
df1
# Out:
#    PatientID     Name   Department     Doctor  BillAmount
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John         NaN
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose         NaN
# 5        101    Alice   Cardiology  Dr. Smith      5000.0

# %%
total_bill_per_dept=df1.groupby('Department')['BillAmount'].sum().reset_index()
print(total_bill_per_dept)
# Out:
#     Department  BillAmount
# 0   Cardiology     16200.0
# 1  Dermatology         0.0
# 2    Neurology         0.0
# 3  Orthopedics      7500.0

# %%
df1.duplicated().sum()
# Out:
# np.int64(1)

# %%
df1.drop_duplicates(subset='PatientID')
# Out:
#    PatientID     Name   Department     Doctor  BillAmount
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John         NaN
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose         NaN

# %%
df1.head()
# Out:
#    PatientID     Name   Department     Doctor  BillAmount
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John         NaN
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose         NaN

# %%
df1.fillna({'BillAmount':df1.BillAmount.mean()},inplace=True)

# %%
df1.head()
# Out:
#    PatientID     Name   Department     Doctor  BillAmount
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John      5925.0
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose      5925.0

# %%
merged_df=pd.merge(df1,df2,on='PatientID')

# %%
merged_df.head()
# Out:
#    PatientID     Name   Department     Doctor  BillAmount  InsuranceCovered  \
# 0        101    Alice   Cardiology  Dr. Smith      5000.0              2000
# 1        102      Bob    Neurology   Dr. John      5925.0              1500
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0              2500
# 3        104    David   Cardiology  Dr. Smith      6200.0              3000
# 4        105      Eva  Dermatology   Dr. Rose      5925.0              1000
#
#    FinalAmount
# 0         3000
# 1         3500
# 2         5000
# 3         3200
# 4         4000

# %%
merged_df.shape
# Out:
# (6, 7)

# %%
new_patients=pd.DataFrame({'PatientID':[106,107],'Name':['James','Rahul'],'Department':['Cardiology','Neurology'],
                           'Doctor':['Dr.Smith','Dr.John'],'BillAmount':[5983,5252],'InsuranceCovered':[1500,2000],'FinalAmount':[3200,4500]})

# %%
new_patients
# Out:
#    PatientID   Name  Department    Doctor  BillAmount  InsuranceCovered  \
# 0        106  James  Cardiology  Dr.Smith        5983              1500
# 1        107  Rahul   Neurology   Dr.John        5252              2000
#
#    FinalAmount
# 0         3200
# 1         4500

# %%
concat_df=pd.concat([merged_df,new_patients],ignore_index=True)

# %%
concat_df
# Out:
#    PatientID     Name   Department     Doctor  BillAmount  InsuranceCovered  \
# 0        101    Alice   Cardiology  Dr. Smith      5000.0            2000.0
# 1        102      Bob    Neurology   Dr. John      5925.0            1500.0
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0            2500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0            3000.0
# 4        105      Eva  Dermatology   Dr. Rose      5925.0            1000.0
# 5        101    Alice   Cardiology  Dr. Smith      5000.0            2000.0
# 6        106    James          NaN        NaN         NaN               NaN
# 7        107    Rahul          NaN        NaN         NaN               NaN
#
#    FinalAmount
# 0       3000.0
# 1       3500.0
# 2       5000.0
# 3       3200.0
# 4       4000.0
# 5       3000.0
# 6          NaN
# 7          NaN

# %%
concat_df.drop_duplicates(inplace=True,ignore_index=True)

# %%
concat_df
# Out:
#    PatientID     Name   Department     Doctor  BillAmount  InsuranceCovered  \
# 0        101    Alice   Cardiology  Dr. Smith      5000.0            2000.0
# 1        102      Bob    Neurology   Dr. John      5925.0            1500.0
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0            2500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0            3000.0
# 4        105      Eva  Dermatology   Dr. Rose      5925.0            1000.0
# 5        106    James          NaN        NaN         NaN               NaN
# 6        107    Rahul          NaN        NaN         NaN               NaN
#
#    FinalAmount
# 0       3000.0
# 1       3500.0
# 2       5000.0
# 3       3200.0
# 4       4000.0
# 5          NaN
# 6          NaN
